# %%
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\wiley\OneDrive\Desktop\NBA_Repo\csv\common_player_info.csv')
df.head()
# Out:
#    person_id first_name     last_name   display_first_last  \
# 0      76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1      76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 2       1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# 3        949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4      76005        Tom     Abernethy        Tom Abernethy
#
#   display_last_comma_first  display_fi_last          player_slug  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 2       Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
# 3     Abdur-Rahim, Shareef   S. Abdur-Rahim  shareef-abdur-rahim
# 4           Abernethy, Tom     T. Abernethy        tom-abernethy
#
#              birthdate          school country  ...  \
# 0  1968-06-24 00:00:00            Duke     USA  ...
# 1  1947-04-16 00:00:00            UCLA     USA  ...
# 2  1974-11-03 00:00:00  San Jose State  France  ...
# ...

# %%
df["year_in_league"] = df["to_year"] - df["from_year"]

# %%
print(df.values)
print(df.columns)
print(df.index)
# Out:
# [[76001 'Alaa' 'Abdelnaby' ... '25' 'N' 4.0]
#  [76003 'Kareem' 'Abdul-Jabbar' ... '1' 'Y' 19.0]
#  [1505 'Tariq' 'Abdul-Wahad' ... '11' 'N' 6.0]
#  ...
#  [78647 'Jim' 'Zoet' ... 'Undrafted' 'N' 0.0]
#  [1627826 'Ivica' 'Zubac' ... '32' 'N' 7.0]
#  [78650 'Matt' 'Zunic' ... nan 'N' 0.0]]
# Index(['person_id', 'first_name', 'last_name', 'display_first_last',
#        'display_last_comma_first', 'display_fi_last', 'player_slug',
#        'birthdate', 'school', 'country', 'last_affiliation', 'height',
#        'weight', 'season_exp', 'jersey', 'position', 'rosterstatus',
#        'games_played_current_season_flag', 'team_id', 'team_name',
#        'team_abbreviation', 'team_code', 'team_city', 'playercode',
#        'from_year', 'to_year', 'dleague_flag', 'nba_flag', 'games_played_flag',
#        'draft_year', 'draft_round', 'draft_number', 'greatest_75_flag',
#        'year_in_league'],
#       dtype='object')
# RangeIndex(start=0, stop=4171, step=1)

# %%
name_school = df[["display_last_comma_first","school"]]
name_school.dropna()
# Out:
#      display_last_comma_first             school
# 0             Abdelnaby, Alaa               Duke
# 1        Abdul-Jabbar, Kareem               UCLA
# 2          Abdul-Wahad, Tariq     San Jose State
# 3        Abdur-Rahim, Shareef         California
# 4              Abernethy, Tom            Indiana
# ...                       ...                ...
# 4166             Zipser, Paul      Bayern Munich
# 4167              Zizic, Ante        Darussafaka
# 4168                Zoet, Jim         Kent State
# 4169             Zubac, Ivica        Mega Basket
# 4170              Zunic, Matt  George Washington
#
# [4156 rows x 2 columns]

# %%
df[df["school"] == "Tennessee"]
# Out:
#       person_id first_name   last_name display_first_last  \
# 45      1629734       Kyle   Alexander     Kyle Alexander
# 352     1629648     Jordan        Bone        Jordan Bone
# 534       76311        Art      Burris         Art Burris
# 639     1631113    Kennedy    Chandler   Kennedy Chandler
# 786       76475      Terry      Crosby       Terry Crosby
# 1061        107       Dale       Ellis         Dale Ellis
# 1437      76899      Ernie    Grunfeld     Ernie Grunfeld
# 1462       2409     Marcus     Haislip     Marcus Haislip
# 1475        984      Steve       Hamer        Steve Hamer
# 1543     202699     Tobias      Harris      Tobias Harris
# 1569      76974   Marshall     Hawkins   Marshall Hawkins
# 1668      77037        Bob     Hogsett        Bob Hogsett
# 1694     203816     Scotty      Hopson      Scotty Hopson
# 1707        275      Allan     Houston      Allan Houston
# 1882    1630553       Keon     Johnson       Keon Johnson
# ...

# %%
schools = ["Tennessee","Alabama","Georgia","South Carolina","Kentucky","Mississippi State", "Mississippi","Vanderbilt","Auburn","Louisiana State","Florida","Arkansas","Missouri"]

# %%
sec_df = df[df["school"].isin(schools)]
sec_df
# Out:
#       person_id first_name   last_name display_first_last  \
# 22      1628389        Bam     Adebayo        Bam Adebayo
# 45      1629734       Kyle   Alexander     Kyle Alexander
# 74         1507      Derek    Anderson     Derek Anderson
# 82        76041        Kim    Anderson       Kim Anderson
# 90         1000    Shandon    Anderson   Shandon Anderson
# ...         ...        ...         ...                ...
# 4071      78582     Nikita      Wilson      Nikita Wilson
# 4090      78600      Brian     Winters      Brian Winters
# 4106    1630218     Robert  Woodard II  Robert Woodard II
# 4138       2428    Vincent   Yarbrough  Vincent Yarbrough
# 4164       2583    Derrick   Zimmerman  Derrick Zimmerman
#
#      display_last_comma_first display_fi_last        player_slug  \
# 22               Adebayo, Bam      B. Adebayo        bam-adebayo
# 45            Alexander, Kyle    K. Alexander     kyle-alexander
# 74            Anderson, Derek     D. Anderson     derek-anderson
# ...

# %%
sec_df.sort_values(["year_in_league"], ascending = [False])
sec_df
# Out:
#       person_id first_name   last_name display_first_last  \
# 22      1628389        Bam     Adebayo        Bam Adebayo
# 45      1629734       Kyle   Alexander     Kyle Alexander
# 74         1507      Derek    Anderson     Derek Anderson
# 82        76041        Kim    Anderson       Kim Anderson
# 90         1000    Shandon    Anderson   Shandon Anderson
# ...         ...        ...         ...                ...
# 4071      78582     Nikita      Wilson      Nikita Wilson
# 4090      78600      Brian     Winters      Brian Winters
# 4106    1630218     Robert  Woodard II  Robert Woodard II
# 4138       2428    Vincent   Yarbrough  Vincent Yarbrough
# 4164       2583    Derrick   Zimmerman  Derrick Zimmerman
#
#      display_last_comma_first display_fi_last        player_slug  \
# 22               Adebayo, Bam      B. Adebayo        bam-adebayo
# 45            Alexander, Kyle    K. Alexander     kyle-alexander
# 74            Anderson, Derek     D. Anderson     derek-anderson
# ...

# %%
print(sec_df["year_in_league"].mean())
print(sec_df["year_in_league"].median())
print(sec_df["year_in_league"].mode())
# Out:
# 4.783068783068783
# 3.0
# 0    0.0
# Name: year_in_league, dtype: float64

# %%
sec_df.loc[sec_df["school"] == "Mississippi"]
# Out:
#       person_id first_name last_name display_first_last  \
# 876     1629056    Terence     Davis      Terence Davis
# 1030      76635    Patrick     Eddie      Patrick Eddie
# 1324      76821     Gerald     Glass       Gerald Glass
# 2715      77705     Johnny   Neumann     Johnny Neumann
# 3079       2770     Justin      Reed        Justin Reed
# 3325       1738       Ansu     Sesay         Ansu Sesay
# 3558      78274       John    Stroud        John Stroud
# 3736      78378     Elston    Turner      Elston Turner
#
#      display_last_comma_first display_fi_last     player_slug  \
# 876            Davis, Terence        T. Davis   terence-davis
# 1030           Eddie, Patrick        P. Eddie   patrick-eddie
# 1324            Glass, Gerald        G. Glass    gerald-glass
# 2715          Neumann, Johnny      J. Neumann  johnny-neumann
# 3079             Reed, Justin         J. Reed     justin-reed
# 3325              Sesay, Ansu        A. Sesay      ansu-sesay
# ...
